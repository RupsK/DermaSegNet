# %%
import pandas as pd
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import time
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
import shutil
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import backend as K
import time
from tqdm import tqdm
from sklearn.metrics import f1_score
from IPython.display import YouTubeVideo
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199
print('All modules have been imported')
# Out:
# All modules have been imported

# %%
def print_in_color(txt_msg,fore_tupple=(0,255,255),back_tupple=(100,100,100)):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    # default parameter print in cyan foreground and gray background
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# example default print
msg='test of default colors'
print_in_color(msg)
# Out:
# test of default colors

# %%
def make_dataframes(train_dir,test_dir):
    dirlist=[train_dir, test_dir]
    names=['train','test']
    zipdir=zip(names, dirlist)
    for name,d in zipdir:
        filepaths=[]
        labels=[]
        classlist=sorted(os.listdir(d) )       
        for klass in classlist:
            sklass=klass[:25] # use only first 25 characters of the class as some are very long
            classpath=os.path.join(d, klass)           
            flist=sorted(os.listdir(classpath)) 
            desc=f'{name:6s}-{sklass:25s}'
            for f in tqdm(flist, ncols=130,desc=desc, unit='files', colour='blue'):
                fpath=os.path.join(classpath,f)
                filepaths.append(fpath)
                labels.append(sklass)
        Fseries=pd.Series(filepaths, name='filepaths')
        Lseries=pd.Series(labels, name='labels')
        df=pd.concat([Fseries, Lseries], axis=1) 
        if name =='test':
            test_df=df       
        else:
            pdf=df
    # create a train_df and a valid_df
    train_df, valid_df = train_test_split(pdf, train_size=.9, shuffle=True, random_state = 123, stratify = pdf['labels'])
    classes=sorted(train_df['labels'].unique())
    class_count=len(classes)
    sample_df=train_df.sample(n=50, replace=False)
    # calculate the average image height and with
    ht=0
    wt=0
    count=0
    for i in range(len(sample_df)):
        fpath=sample_df['filepaths'].iloc[i]
        try:
            img=cv2.imread(fpath)
            h=img.shape[0]
            w=img.shape[1]
            wt +=w
            ht +=h
            count +=1
        except:
            pass
    have=int(ht/count)
    wave=int(wt/count)
    aspect_ratio=have/wave
    print('number of classes in processed dataset= ', class_count)    
    counts=list(train_df['labels'].value_counts())    
    print('the maximum files in any class in train_df is ', max(counts), '  the minimum files in any class in train_df is ', min(counts))
    print('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))  
    print('average image height= ', have, '  average image width= ', wave, ' aspect ratio h/w= ', aspect_ratio)    
    return train_df, test_df, valid_df, classes, class_count

train_dir = r'C:/Users/VRAR/Desktop/Combine23class/train' #C:/Users/VRAR/Desktop/Dermnet
test_dir=r'C:/Users/VRAR/Desktop/Combine23Class/test'
train_df, test_df, valid_df, classes, class_count=make_dataframes(train_dir, test_dir)
# Out:
# train -Acne and Rosacea Photos  : 100%|████████████████████████████████████████████████| 2520/2520 [00:00<00:00, 360050.62files/s]
# train -Actinic Keratosis Basal C: 100%|████████████████████████████████████████████████| 2298/2298 [00:00<00:00, 326176.33files/s]
# train -Atopic Dermatitis Photos : 100%|██████████████████████████████████████████████████| 978/978 [00:00<00:00, 326049.54files/s]
# train -Bullous Disease Photos   : 100%|██████████████████████████████████████████████████| 896/896 [00:00<00:00, 177872.79files/s]
# train -Cellulitis Impetigo and o: 100%|██████████████████████████████████████████████████| 576/576 [00:00<00:00, 192350.25files/s]
# train -Eczema Photos            : 100%|████████████████████████████████████████████████| 2470/2470 [00:00<00:00, 144750.40files/s]
# train -Exanthems and Drug Erupti: 100%|██████████████████████████████████████████████████| 808/808 [00:00<00:00, 162987.43files/s]
# train -Hair Loss Photos Alopecia: 100%|██████████████████████████████████████████████████| 478/478 [00:00<00:00, 159382.89files/s]
# train -Herpes HPV and other STDs: 100%|██████████████████████████████████████████████████| 810/810 [00:00<00:00, 133892.42files/s]
# train -Light Diseases and Disord: 100%|████████████████████████████████████████████████| 1136/1136 [00:00<00:00, 162247.74files/s]
# train -Lupus and other Connectiv: 100%|██████████████████████████████████████████████████| 840/840 [00:00<00:00, 279953.54files/s]
# train -Melanoma Skin Cancer Nevi: 100%|██████████████████████████████████████████████████| 926/926 [00:00<00:00, 308983.73files/s]
# train -Nail Fungus and other Nai: 100%|████████████████████████████████████████████████| 2080/2080 [00:00<00:00, 259763.36files/s]
# train -Poison Ivy Photos and oth: 100%|██████████████████████████████████████████████████| 520/520 [00:00<00:00, 104057.16files/s]
# train -Psoriasis pictures Lichen: 100%|████████████████████████████████████████████████| 2810/2810 [00:00<00:00, 133448.00files/s]
# train -Scabies Lyme Disease and : 100%|██████████████████████████████████████████████████| 862/862 [00:00<00:00, 122256.45files/s]
# train -Seborrheic Keratoses and : 100%|█████████████████████████████████████████████████| 2742/2742 [00:00<00:00, 91261.56files/s]
# train -Systemic Disease         : 100%|████████████████████████████████████████████████| 1212/1212 [00:00<00:00, 133980.72files/s]
# train -Tinea Ringworm Candidiasi: 100%|████████████████████████████████████████████████| 2601/2601 [00:00<00:00, 113079.91files/s]
# train -Urticaria Hives          : 100%|██████████████████████████████████████████████████| 424/424 [00:00<00:00, 212801.83files/s]
# train -Vascular Tumors          : 100%|██████████████████████████████████████████████████| 964/964 [00:00<00:00, 107801.45files/s]
# train -Vasculitis Photos        : 100%|██████████████████████████████████████████████████| 832/832 [00:00<00:00, 104047.85files/s]
# train -Warts Molluscum and other: 100%|████████████████████████████████████████████████| 2172/2172 [00:00<00:00, 108353.39files/s]
# test  -Acne and Rosacea Photos  : 100%|██████████████████████████████████████████████████| 312/312 [00:00<00:00, 329296.14files/s]
# test  -Actinic Keratosis Basal C: 100%|██████████████████████████████████████████████████| 289/289 [00:00<00:00, 288539.36files/s]
# test  -Atopic Dermatitis Photos : 100%|██████████████████████████████████████████████████| 123/123 [00:00<00:00, 123509.55files/s]
# test  -Bullous Disease Photos   : 100%|██████████████████████████████████████████████████████████████| 113/113 [00:00<?, ?files/s]
# test  -Cellulitis Impetigo and o: 100%|█████████████████████████████████████████████████████| 73/73 [00:00<00:00, 72935.73files/s]
# test  -Eczema Photos            : 100%|██████████████████████████████████████████████████| 309/309 [00:00<00:00, 309096.10files/s]
# test  -Exanthems and Drug Erupti: 100%|██████████████████████████████████████████████████| 101/101 [00:00<00:00, 101007.32files/s]
# test  -Hair Loss Photos Alopecia: 100%|████████████████████████████████████████████████████████████████| 60/60 [00:00<?, ?files/s]
# test  -Herpes HPV and other STDs: 100%|██████████████████████████████████████████████████| 102/102 [00:00<00:00, 102275.64files/s]
# test  -Light Diseases and Disord: 100%|██████████████████████████████████████████████████████████████| 143/143 [00:00<?, ?files/s]
# test  -Lupus and other Connectiv: 100%|██████████████████████████████████████████████████████████████| 105/105 [00:00<?, ?files/s]
# test  -Melanoma Skin Cancer Nevi: 100%|██████████████████████████████████████████████████████████████| 116/116 [00:00<?, ?files/s]
# test  -Nail Fungus and other Nai: 100%|███████████████████████████████████████████████████| 261/261 [00:00<00:00, 87151.77files/s]
# test  -Poison Ivy Photos and oth: 100%|█████████████████████████████████████████████████████| 65/65 [00:00<00:00, 65253.65files/s]
# test  -Psoriasis pictures Lichen: 100%|██████████████████████████████████████████████████| 352/352 [00:00<00:00, 175782.24files/s]
# test  -Scabies Lyme Disease and : 100%|██████████████████████████████████████████████████████████████| 108/108 [00:00<?, ?files/s]
# test  -Seborrheic Keratoses and : 100%|███████████████████████████████████████████████████| 343/343 [00:00<00:00, 49018.58files/s]
# test  -Systemic Disease         : 100%|██████████████████████████████████████████████████| 152/152 [00:00<00:00, 152156.14files/s]
# test  -Tinea Ringworm Candidiasi: 100%|██████████████████████████████████████████████████| 325/325 [00:00<00:00, 162202.38files/s]
# test  -Urticaria Hives          : 100%|████████████████████████████████████████████████████████████████| 53/53 [00:00<?, ?files/s]
# test  -Vascular Tumors          : 100%|██████████████████████████████████████████████████| 121/121 [00:00<00:00, 121008.77files/s]
# test  -Vasculitis Photos        : 100%|██████████████████████████████████████████████████| 105/105 [00:00<00:00, 104857.60files/s]
# test  -Warts Molluscum and other: 100%|██████████████████████████████████████████████████| 272/272 [00:00<00:00, 136123.46files/s]
# number of classes in processed dataset=  23
# the maximum files in any class in train_df is  2529   the minimum files in any class in train_df is  382
# train_df length:  28759   test_df length:  4003   valid_df length:  3196
# average image height=  380   average image width=  442  aspect ratio h/w=  0.8597285067873304

# %%
def trim(df, max_samples, min_samples, column):
    df=df.copy()
    classes=df[column].unique()
    class_count=len(classes)
    length=len(df)
    print ('dataframe initially is of length ',length, ' with ', class_count, ' classes')
    groups=df.groupby(column)    
    trimmed_df = pd.DataFrame(columns = df.columns)
    groups=df.groupby(column)
    for label in df[column].unique(): 
        group=groups.get_group(label)
        count=len(group)    
        if count > max_samples:
            sampled_group=group.sample(n=max_samples, random_state=123,axis=0)
            trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
        else:
            if count>=min_samples:
                sampled_group=group        
                trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
    print('after trimming, the maximum samples in any class is now ',max_samples, ' and the minimum samples in any class is ', min_samples)
    classes=trimmed_df[column].unique()# return this in case some classes have less than min_samples
    class_count=len(classes) # return this in case some classes have less than min_samples
    length=len(trimmed_df)
    print ('the trimmed dataframe now is of length ',length, ' with ', class_count, ' classes')
    return trimmed_df, classes, class_count

max_samples=900  # LIMIT MAXIMUM IMAGE SAMPLES IN ANY CLASS TO 160 IMAGES TO HELP BALANCE THE DATASET
min_samples=191
column='labels'
train_df, classes, class_count=trim(train_df, max_samples, min_samples, column)
# Out:
# dataframe initially is of length  28759  with  23  classes
# after trimming, the maximum samples in any class is now  900  and the minimum samples in any class is  191
# the trimmed dataframe now is of length  17922  with  23  classes

# %%
def balance(df, n, working_dir, img_size):
    df=df.copy()
    print('Initial length of dataframe is ', len(df))
    aug_dir=os.path.join(working_dir, 'aug')# directory to store augmented images
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)        
    for label in df['labels'].unique():    
        dir_path=os.path.join(aug_dir,label)    
        os.mkdir(dir_path) # make class directories within aug directory
    # create and store the augmented images  
    total=0
    gen=ImageDataGenerator(horizontal_flip=True,  rotation_range=20, width_shift_range=.2,
                                  height_shift_range=.2, zoom_range=.2)
    groups=df.groupby('labels') # group by class
    for label in df['labels'].unique():  # for every class               
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label 
        sample_count=len(group)   # determine how many samples there are in this class  
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            target_dir=os.path.join(aug_dir, label)  # define where to write the images
            msg='{0:40s} for class {1:^30s} creating {2:^5s} augmented images'.format(' ', label, str(delta))
            print(msg, '\r', end='') # prints over on the same line
            aug_gen=gen.flow_from_dataframe( group,  x_col='filepaths', y_col=None, target_size=img_size,
                                            class_mode=None, batch_size=1, shuffle=False, 
                                            save_to_dir=target_dir, save_prefix='aug-', color_mode='rgb',
                                            save_format='jpg')
            while aug_img_count<delta:
                images=next(aug_gen)            
                aug_img_count += len(images)
            total +=aug_img_count
    print('Total Augmented images created= ', total)
    # create aug_df and merge with train_df to create composite training set ndf
    aug_fpaths=[]
    aug_labels=[]
    classlist=os.listdir(aug_dir)
    for klass in classlist:
        classpath=os.path.join(aug_dir, klass)     
        flist=os.listdir(classpath)    
        for f in flist:        
            fpath=os.path.join(classpath,f)         
            aug_fpaths.append(fpath)
            aug_labels.append(klass)
    Fseries=pd.Series(aug_fpaths, name='filepaths')
    Lseries=pd.Series(aug_labels, name='labels')
    aug_df=pd.concat([Fseries, Lseries], axis=1)         
    df=pd.concat([df,aug_df], axis=0).reset_index(drop=True)
    print('Length of augmented dataframe is now ', len(df))
    return df 

n=600
working_dir=r'./'
img_size = (224, 260) # img size will significantly impact training time
train_df=balance(train_df, n, working_dir, img_size)
# Out:
# Initial length of dataframe is  17922
# Found 382 validated image filenames.     for class        Urticaria Hives         creating  218  augmented images
# Found 518 validated image filenames.     for class   Cellulitis Impetigo and o    creating  82   augmented images
# Found 430 validated image filenames.     for class   Hair Loss Photos Alopecia    creating  170  augmented images
# Found 468 validated image filenames.     for class   Poison Ivy Photos and oth    creating  132  augmented images
# Total Augmented images created=  602
# Length of augmented dataframe is now  18524

# %%
def make_gens(batch_size, train_df, test_df, valid_df, img_size, use_scientific=False): 
    ycol='labels'
    trgen=ImageDataGenerator(horizontal_flip=True)    
    t_and_v_gen=ImageDataGenerator()
    msg='{0:70s} for train generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col=ycol, target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
    msg='{0:70s} for valid generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col=ycol, target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
    # for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
    # this insures that we go through all the sample in the test set exactly once.
    length=len(test_df)
    test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
    test_steps=int(length/test_batch_size)    
    msg='{0:70s} for test generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col=ycol , target_size=img_size,
                                       class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
    # from the generator we can get information we will need later
    classes=list(train_gen.class_indices.keys())
    class_indices=list(train_gen.class_indices.values())
    class_count=len(classes)
    labels=test_gen.labels
    print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
    return train_gen, test_gen, valid_gen, test_batch_size, test_steps, classes


batch_size=30
use_scientific=False # if set to true will use scientific labels, otherwise use common name labels
train_gen, test_gen, valid_gen, test_batch_size, test_steps, classes=make_gens(batch_size, train_df, test_df, valid_df, img_size,use_scientific=use_scientific)
# Out:
# Found 18524 validated image filenames belonging to 23 classes.         for train generator
# Found 3195 validated image filenames belonging to 23 classes.          for valid generator
# Found 4002 validated image filenames belonging to 23 classes.          for test generator
# test batch size:  1   test steps:  4003  number of classes :  23

# %%
def make_model(img_size, lr, mod_num=3):  
    img_shape=(img_size[0], img_size[1], 3)
    if mod_num == 0:
        base_model=tf.keras.applications.efficientnet.EfficientNetB0(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B0 model'
    elif mod_num == 3:
        base_model=tf.keras.applications.efficientnet.EfficientNetB3(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
        msg='Created EfficientNet B3 model'
    elif mod_num == 5:
        base_model=tf.keras.applications.efficientnet.EfficientNetB5(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
        msg='Created EfficientNet B5 model'
        
    else:
        base_model=tf.keras.applications.efficientnet.EfficientNetB7(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B7 model'   
   
    base_model.trainable=True
    x=base_model.output
    x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
    x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                    bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
    x=Dropout(rate=.4, seed=123)(x)       
    output=Dense(class_count, activation='softmax')(x)
    model=Model(inputs=base_model.input, outputs=output)
    model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy']) 
    msg=msg + f' with initial learning rate set to {lr}'
    print_in_color(msg)
    return model

lr=.001
model=make_model(img_size, lr) # using B3 model by default
# Out:
# Created EfficientNet B3 model with initial learning rate set to 0.001

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch, dwell=True, factor=.4): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.lowest_aloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        self.plist=[]
        self.alist=[]
        self.dwell= dwell
        self.factor=factor
        
    def get_list(self): # define a function to return the list of % validation change
        return self.plist, self.alist
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            msg =f'Training will proceed until epoch {ask_epoch} then you will be asked to' 
            print_in_color(msg )
            msg='enter H to halt training or enter an integer for how many more epochs to run then be asked again'
            print_in_color(msg)
            if self.dwell:
                msg='learning rate will be automatically adjusted during training'
                print_in_color(msg, (0,255,0))
        self.start_time= time.time() # set the time at which training started
       
    def on_train_end(self, logs=None):   # runs at the end of training  
        msg=f'loading model with weights from epoch {self.best_epoch}'
        print_in_color(msg, (0,255,255))
        model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print_in_color (msg) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        vloss=logs.get('val_loss')  # get the validation loss for this epoch
        aloss=logs.get('loss')
        if epoch >0:
            deltav = self.lowest_vloss- vloss 
            pimprov=(deltav/self.lowest_vloss) * 100 
            self.plist.append(pimprov)
            deltaa=self.lowest_aloss-aloss
            aimprov=(deltaa/self.lowest_aloss) * 100
            self.alist.append(aimprov)
        else:
            pimprov=0.0 
            aimprov=0.0
        if vloss< self.lowest_vloss:
            self.lowest_vloss=vloss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1            
            msg=f'\n validation loss of {vloss:7.4f} is {pimprov:7.4f} % below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights'
            print_in_color(msg, (0,255,0)) # green foreground
        else: # validation loss increased
            pimprov=abs(pimprov)
            msg=f'\n validation loss of {vloss:7.4f} is {pimprov:7.4f} % above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights'
            print_in_color(msg, (255,255,0)) # yellow foreground
            if self.dwell: # if dwell is True when the validation loss increases the learning rate is automatically reduced and model weights are set to best weights
                lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                new_lr=lr * self.factor
                msg=f'learning rate was automatically adjusted from {lr:8.6f} to {new_lr:8.6f}, model weights set to best weights'
                print_in_color(msg) # cyan foreground
                tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                model.set_weights(self.best_weights) # set the weights of the model to the best weights      
                
        if aloss< self.lowest_aloss:
            self.lowest_aloss=aloss        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                msg='\n Enter H to end training or  an integer for the number of additional epochs to run then ask again'
                print_in_color(msg) # cyan foreground
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    msg=f'you entered {ans},  Training halted on epoch {epoch+1} due to user input\n'
                    print_in_color(msg)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        msg=f'you entered {ans} Training will continue to epoch {self.ask_epoch}'
                        print_in_color(msg) # cyan foreground
                        if self.dwell==False:
                            lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                            msg=f'current LR is  {lr:8.6f}  hit enter to keep  this LR or enter a new LR'
                            print_in_color(msg) # cyan foreground
                            ans=input(' ')
                            if ans =='':
                                msg=f'keeping current LR of {lr:7.5f}'
                                print_in_color(msg) # cyan foreground
                            else:
                                new_lr=float(ans)
                                tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                                msg=f' changing LR to {ans}'
                                print_in_color(msg) # cyan foreground

# %%
epochs=40
ask_epoch=12
ask=LR_ASK(model, epochs,  ask_epoch)
callbacks=[ask]

# %%
tf.keras.metrics.TopKCategoricalAccuracy(
    k=5, name="top_k_categorical_accuracy", dtype=None
)
def make_model(img_size, lr, mod_num=3):  
    img_shape=(img_size[0], img_size[1], 3)
    if mod_num == 0:
        base_model=tf.keras.applications.efficientnet.EfficientNetB0(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B0 model'
    elif mod_num == 3:
        base_model=tf.keras.applications.efficientnet.EfficientNetB7(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
        msg='Created EfficientNet B3 model'
    elif mod_num == 5:
        base_model=tf.keras.applications.efficientnet.EfficientNetB5(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
        msg='Created EfficientNet B5 model'
        
    else:
        base_model=tf.keras.applications.efficientnet.EfficientNetB7(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B7 model'   
   
    base_model.trainable=True
    x=base_model.output
    x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
    x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                    bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
    x=Dropout(rate=.4, seed=123)(x)       
    output=Dense(class_count, activation='softmax')(x)
    model=Model(inputs=base_model.input, outputs=output)
    model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy','TopKCategoricalAccuracy']) 
    msg=msg + f' with initial learning rate set to {lr}'
    print_in_color(msg)
    return model

lr=.001
model=make_model(img_size, lr) # using B3 model by default
# Out:
# Created EfficientNet B3 model with initial learning rate set to 0.001

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch, dwell=True, factor=.4): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.lowest_aloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        self.plist=[]
        self.alist=[]
        self.dwell= dwell
        self.factor=factor
        
    def get_list(self): # define a function to return the list of % validation change
        return self.plist, self.alist
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            msg =f'Training will proceed until epoch {ask_epoch} then you will be asked to' 
            print_in_color(msg )
            msg='enter H to halt training or enter an integer for how many more epochs to run then be asked again'
            print_in_color(msg)
            if self.dwell:
                msg='learning rate will be automatically adjusted during training'
                print_in_color(msg, (0,255,0))
        self.start_time= time.time() # set the time at which training started
       
    def on_train_end(self, logs=None):   # runs at the end of training  
        msg=f'loading model with weights from epoch {self.best_epoch}'
        print_in_color(msg, (0,255,255))
        model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print_in_color (msg) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        vloss=logs.get('val_loss')  # get the validation loss for this epoch
        aloss=logs.get('loss')
        if epoch >0:
            deltav = self.lowest_vloss- vloss 
            pimprov=(deltav/self.lowest_vloss) * 100 
            self.plist.append(pimprov)
            deltaa=self.lowest_aloss-aloss
            aimprov=(deltaa/self.lowest_aloss) * 100
            self.alist.append(aimprov)
        else:
            pimprov=0.0 
            aimprov=0.0
        if vloss< self.lowest_vloss:
            self.lowest_vloss=vloss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1            
            msg=f'\n validation loss of {vloss:7.4f} is {pimprov:7.4f} % below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights'
            print_in_color(msg, (0,255,0)) # green foreground
        else: # validation loss increased
            pimprov=abs(pimprov)
            msg=f'\n validation loss of {vloss:7.4f} is {pimprov:7.4f} % above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights'
            print_in_color(msg, (255,255,0)) # yellow foreground
            if self.dwell: # if dwell is True when the validation loss increases the learning rate is automatically reduced and model weights are set to best weights
                lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                new_lr=lr * self.factor
                msg=f'learning rate was automatically adjusted from {lr:8.6f} to {new_lr:8.6f}, model weights set to best weights'
                print_in_color(msg) # cyan foreground
                tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                model.set_weights(self.best_weights) # set the weights of the model to the best weights      
                
        if aloss< self.lowest_aloss:
            self.lowest_aloss=aloss        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                msg='\n Enter H to end training or  an integer for the number of additional epochs to run then ask again'
                print_in_color(msg) # cyan foreground
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    msg=f'you entered {ans},  Training halted on epoch {epoch+1} due to user input\n'
                    print_in_color(msg)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        msg=f'you entered {ans} Training will continue to epoch {self.ask_epoch}'
                        print_in_color(msg) # cyan foreground
                        if self.dwell==False:
                            lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                            msg=f'current LR is  {lr:8.6f}  hit enter to keep  this LR or enter a new LR'
                            print_in_color(msg) # cyan foreground
                            ans=input(' ')
                            if ans =='':
                                msg=f'keeping current LR of {lr:7.5f}'
                                print_in_color(msg) # cyan foreground
                            else:
                                new_lr=float(ans)
                                tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                                msg=f' changing LR to {ans}'
                                print_in_color(msg) # cyan foreground

# %%
epochs=40
ask_epoch=30
ask=LR_ASK(model, epochs,  ask_epoch)
callbacks=[ask]

# %%
history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 30 then you will be asked to
#
# enter H to halt training or enter an integer for how many more epochs to run then be asked again
#
# learning rate will be automatically adjusted during training
#
# Epoch 1/40
# 618/618 [==============================] - ETA: 0s - loss: 7.9371 - accuracy: 0.2348 - top_k_categorical_accuracy: 0.5428
#  validation loss of  5.3499 is  0.0000 % below lowest loss, saving weights from epoch 1   as best weights
#
# 618/618 [==============================] - 22171s 36s/step - loss: 7.9371 - accuracy: 0.2348 - top_k_categorical_accuracy: 0.5428 - val_loss: 5.3499 - val_accuracy: 0.3534 - val_top_k_categorical_accuracy: 0.7149
# Epoch 2/40
# 618/618 [==============================] - ETA: 0s - loss: 4.0458 - accuracy: 0.4413 - top_k_categorical_accuracy: 0.7777
#  validation loss of  3.1550 is 41.0269 % below lowest loss, saving weights from epoch 2   as best weights
#
# 618/618 [==============================] - 22083s 36s/step - loss: 4.0458 - accuracy: 0.4413 - top_k_categorical_accuracy: 0.7777 - val_loss: 3.1550 - val_accuracy: 0.4736 - val_top_k_categorical_accuracy: 0.8091
# Epoch 3/40
# 618/618 [==============================] - ETA: 0s - loss: 2.4190 - accuracy: 0.6053 - top_k_categorical_accuracy: 0.8757
#  validation loss of  2.1979 is 30.3364 % below lowest loss, saving weights from epoch 3   as best weights
#
# 618/618 [==============================] - 23153s 37s/step - loss: 2.4190 - accuracy: 0.6053 - top_k_categorical_accuracy: 0.8757 - val_loss: 2.1979 - val_accuracy: 0.5912 - val_top_k_categorical_accuracy: 0.8620
# Epoch 4/40
# 618/618 [==============================] - ETA: 0s - loss: 1.6322 - accuracy: 0.7399 - top_k_categorical_accuracy: 0.9355
#  validation loss of  1.8614 is 15.3106 % below lowest loss, saving weights from epoch 4   as best weights
#
# 618/618 [==============================] - 22899s 37s/step - loss: 1.6322 - accuracy: 0.7399 - top_k_categorical_accuracy: 0.9355 - val_loss: 1.8614 - val_accuracy: 0.6407 - val_top_k_categorical_accuracy: 0.8967
# Epoch 5/40
# 618/618 [==============================] - ETA: 0s - loss: 1.1870 - accuracy: 0.8276 - top_k_categorical_accuracy: 0.9695
#  validation loss of  1.6733 is 10.1031 % below lowest loss, saving weights from epoch 5   as best weights
#
# 618/618 [==============================] - 22764s 37s/step - loss: 1.1870 - accuracy: 0.8276 - top_k_categorical_accuracy: 0.9695 - val_loss: 1.6733 - val_accuracy: 0.6729 - val_top_k_categorical_accuracy: 0.9042
# Epoch 6/40
# 618/618 [==============================] - ETA: 0s - loss: 0.9291 - accuracy: 0.8817 - top_k_categorical_accuracy: 0.9828
#  validation loss of  1.5671 is  6.3473 % below lowest loss, saving weights from epoch 6   as best weights
#
# 618/618 [==============================] - 23218s 38s/step - loss: 0.9291 - accuracy: 0.8817 - top_k_categorical_accuracy: 0.9828 - val_loss: 1.5671 - val_accuracy: 0.7074 - val_top_k_categorical_accuracy: 0.9164
# Epoch 7/40
# 618/618 [==============================] - ETA: 0s - loss: 0.7656 - accuracy: 0.9121 - top_k_categorical_accuracy: 0.9909
#  validation loss of  1.4270 is  8.9395 % below lowest loss, saving weights from epoch 7   as best weights
#
# 618/618 [==============================] - 22721s 37s/step - loss: 0.7656 - accuracy: 0.9121 - top_k_categorical_accuracy: 0.9909 - val_loss: 1.4270 - val_accuracy: 0.7230 - val_top_k_categorical_accuracy: 0.9174
# Epoch 8/40
# 618/618 [==============================] - ETA: 0s - loss: 0.6622 - accuracy: 0.9291 - top_k_categorical_accuracy: 0.9948
#  validation loss of  1.3871 is  2.7966 % below lowest loss, saving weights from epoch 8   as best weights
#
# 618/618 [==============================] - 23464s 38s/step - loss: 0.6622 - accuracy: 0.9291 - top_k_categorical_accuracy: 0.9948 - val_loss: 1.3871 - val_accuracy: 0.7321 - val_top_k_categorical_accuracy: 0.9167
# Epoch 9/40
# 618/618 [==============================] - ETA: 0s - loss: 0.5790 - accuracy: 0.9428 - top_k_categorical_accuracy: 0.9962
#  validation loss of  1.3923 is  0.3724 % above lowest loss of  1.3871 keeping weights from epoch 8 as best weights
#
# learning rate was automatically adjusted from 0.001000 to 0.000400, model weights set to best weights
#
# 618/618 [==============================] - 23518s 38s/step - loss: 0.5790 - accuracy: 0.9428 - top_k_categorical_accuracy: 0.9962 - val_loss: 1.3923 - val_accuracy: 0.7418 - val_top_k_categorical_accuracy: 0.9227
# Epoch 10/40
# 618/618 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.9642 - top_k_categorical_accuracy: 0.9979
#  validation loss of  1.1945 is 13.8848 % below lowest loss, saving weights from epoch 10  as best weights
#
# 618/618 [==============================] - 22697s 37s/step - loss: 0.4933 - accuracy: 0.9642 - top_k_categorical_accuracy: 0.9979 - val_loss: 1.1945 - val_accuracy: 0.7778 - val_top_k_categorical_accuracy: 0.9343
# Epoch 11/40
# 618/618 [==============================] - ETA: 0s - loss: 0.4044 - accuracy: 0.9734 - top_k_categorical_accuracy: 0.9989
#  validation loss of  1.1510 is  3.6436 % below lowest loss, saving weights from epoch 11  as best weights
#
# 618/618 [==============================] - 23305s 38s/step - loss: 0.4044 - accuracy: 0.9734 - top_k_categorical_accuracy: 0.9989 - val_loss: 1.1510 - val_accuracy: 0.7865 - val_top_k_categorical_accuracy: 0.9371
# Epoch 12/40
# 618/618 [==============================] - ETA: 0s - loss: 0.3671 - accuracy: 0.9772 - top_k_categorical_accuracy: 0.9996
#  validation loss of  1.1471 is  0.3370 % below lowest loss, saving weights from epoch 12  as best weights
#
# 618/618 [==============================] - 22561s 37s/step - loss: 0.3671 - accuracy: 0.9772 - top_k_categorical_accuracy: 0.9996 - val_loss: 1.1471 - val_accuracy: 0.7797 - val_top_k_categorical_accuracy: 0.9327
# Epoch 13/40
# 618/618 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.9811 - top_k_categorical_accuracy: 0.9996
#  validation loss of  1.1485 is  0.1176 % above lowest loss of  1.1471 keeping weights from epoch 12 as best weights
#
# learning rate was automatically adjusted from 0.000400 to 0.000160, model weights set to best weights
#
# 618/618 [==============================] - 22462s 36s/step - loss: 0.3393 - accuracy: 0.9811 - top_k_categorical_accuracy: 0.9996 - val_loss: 1.1485 - val_accuracy: 0.7869 - val_top_k_categorical_accuracy: 0.9311
# Epoch 14/40
# 618/618 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.9826 - top_k_categorical_accuracy: 0.9996
#  validation loss of  1.1039 is  3.7708 % below lowest loss, saving weights from epoch 14  as best weights
#
# 618/618 [==============================] - 22657s 37s/step - loss: 0.3305 - accuracy: 0.9826 - top_k_categorical_accuracy: 0.9996 - val_loss: 1.1039 - val_accuracy: 0.7887 - val_top_k_categorical_accuracy: 0.9387
# Epoch 15/40
# 618/618 [==============================] - ETA: 0s - loss: 0.3095 - accuracy: 0.9855 - top_k_categorical_accuracy: 0.9998
#  validation loss of  1.0974 is  0.5842 % below lowest loss, saving weights from epoch 15  as best weights
#
# 618/618 [==============================] - 22981s 37s/step - loss: 0.3095 - accuracy: 0.9855 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.0974 - val_accuracy: 0.7894 - val_top_k_categorical_accuracy: 0.9387
# Epoch 16/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2973 - accuracy: 0.9862 - top_k_categorical_accuracy: 0.9998
#  validation loss of  1.0795 is  1.6337 % below lowest loss, saving weights from epoch 16  as best weights
# 618/618 [==============================] - 21709s 35s/step - loss: 0.2973 - accuracy: 0.9862 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.0795 - val_accuracy: 0.7956 - val_top_k_categorical_accuracy: 0.9390
# Epoch 17/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.9870 - top_k_categorical_accuracy: 0.9998
#  validation loss of  1.0814 is  0.1814 % above lowest loss of  1.0795 keeping weights from epoch 16 as best weights
#
# learning rate was automatically adjusted from 0.000160 to 0.000064, model weights set to best weights
#
# 618/618 [==============================] - 21623s 35s/step - loss: 0.2867 - accuracy: 0.9870 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.0814 - val_accuracy: 0.7919 - val_top_k_categorical_accuracy: 0.9355
# Epoch 18/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.9874 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0776 is  0.1757 % below lowest loss, saving weights from epoch 18  as best weights
#
# 618/618 [==============================] - 21910s 35s/step - loss: 0.2865 - accuracy: 0.9874 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0776 - val_accuracy: 0.7959 - val_top_k_categorical_accuracy: 0.9396
# Epoch 19/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.9876 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0766 is  0.0957 % below lowest loss, saving weights from epoch 19  as best weights
#
# 618/618 [==============================] - 22409s 36s/step - loss: 0.2797 - accuracy: 0.9876 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0766 - val_accuracy: 0.7944 - val_top_k_categorical_accuracy: 0.9412
# Epoch 20/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2744 - accuracy: 0.9881 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0683 is  0.7708 % below lowest loss, saving weights from epoch 20  as best weights
#
# 618/618 [==============================] - 22136s 36s/step - loss: 0.2744 - accuracy: 0.9881 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0683 - val_accuracy: 0.7981 - val_top_k_categorical_accuracy: 0.9430
# Epoch 21/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.9875 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0647 is  0.3288 % below lowest loss, saving weights from epoch 21  as best weights
#
# 618/618 [==============================] - 21525s 35s/step - loss: 0.2739 - accuracy: 0.9875 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0647 - val_accuracy: 0.7956 - val_top_k_categorical_accuracy: 0.9396
# Epoch 22/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.9884 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0707 is  0.5570 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000064 to 0.000026, model weights set to best weights
#
# 618/618 [==============================] - 21024s 34s/step - loss: 0.2682 - accuracy: 0.9884 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0707 - val_accuracy: 0.7947 - val_top_k_categorical_accuracy: 0.9387
# Epoch 23/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9881 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0715 is  0.6309 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000026 to 0.000010, model weights set to best weights
#
# 618/618 [==============================] - 20914s 34s/step - loss: 0.2664 - accuracy: 0.9881 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0715 - val_accuracy: 0.7959 - val_top_k_categorical_accuracy: 0.9415
# Epoch 24/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9893 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0693 is  0.4264 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000010 to 0.000004, model weights set to best weights
#
# 618/618 [==============================] - 21066s 34s/step - loss: 0.2661 - accuracy: 0.9893 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0693 - val_accuracy: 0.7962 - val_top_k_categorical_accuracy: 0.9412
# Epoch 25/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2680 - accuracy: 0.9891 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0658 is  0.0972 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000004 to 0.000002, model weights set to best weights
#
# 618/618 [==============================] - 20977s 34s/step - loss: 0.2680 - accuracy: 0.9891 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0658 - val_accuracy: 0.7969 - val_top_k_categorical_accuracy: 0.9427
# Epoch 26/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.9896 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0717 is  0.6501 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000002 to 0.000001, model weights set to best weights
#
# 618/618 [==============================] - 20718s 34s/step - loss: 0.2662 - accuracy: 0.9896 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0717 - val_accuracy: 0.7972 - val_top_k_categorical_accuracy: 0.9402
# Epoch 27/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9897 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0654 is  0.0635 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000001 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 20718s 34s/step - loss: 0.2667 - accuracy: 0.9897 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0654 - val_accuracy: 0.7978 - val_top_k_categorical_accuracy: 0.9415
# Epoch 28/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9893 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0704 is  0.5272 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 20427s 33s/step - loss: 0.2667 - accuracy: 0.9893 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0704 - val_accuracy: 0.7950 - val_top_k_categorical_accuracy: 0.9405
# Epoch 29/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.9895 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0664 is  0.1556 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 20171s 33s/step - loss: 0.2670 - accuracy: 0.9895 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0664 - val_accuracy: 0.7978 - val_top_k_categorical_accuracy: 0.9405
# Epoch 30/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.9896 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0737 is  0.8459 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
#
# 9
# you entered 9 Training will continue to epoch 39
#
# 618/618 [==============================] - 67814s 110s/step - loss: 0.2650 - accuracy: 0.9896 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0737 - val_accuracy: 0.7953 - val_top_k_categorical_accuracy: 0.9405
# Epoch 31/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.9885 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0673 is  0.2435 % above lowest loss of  1.0647 keeping weights from epoch 21 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 20437s 33s/step - loss: 0.2687 - accuracy: 0.9885 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0673 - val_accuracy: 0.7984 - val_top_k_categorical_accuracy: 0.9402
# Epoch 32/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9890 - top_k_categorical_accuracy: 0.9999
#  validation loss of  1.0634 is  0.1308 % below lowest loss, saving weights from epoch 32  as best weights
#
# 618/618 [==============================] - 20707s 34s/step - loss: 0.2681 - accuracy: 0.9890 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0634 - val_accuracy: 0.7972 - val_top_k_categorical_accuracy: 0.9418
# Epoch 33/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.9899 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0666 is  0.3091 % above lowest loss of  1.0634 keeping weights from epoch 32 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 21427s 35s/step - loss: 0.2654 - accuracy: 0.9899 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0666 - val_accuracy: 0.7984 - val_top_k_categorical_accuracy: 0.9399
# Epoch 34/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.9893 - top_k_categorical_accuracy: 0.9998
#  validation loss of  1.0723 is  0.8412 % above lowest loss of  1.0634 keeping weights from epoch 32 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 21622s 35s/step - loss: 0.2652 - accuracy: 0.9893 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.0723 - val_accuracy: 0.7950 - val_top_k_categorical_accuracy: 0.9399
# Epoch 35/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.9901 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0644 is  0.0959 % above lowest loss of  1.0634 keeping weights from epoch 32 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 21558s 35s/step - loss: 0.2655 - accuracy: 0.9901 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0644 - val_accuracy: 0.7966 - val_top_k_categorical_accuracy: 0.9402
# Epoch 36/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9893 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0671 is  0.3501 % above lowest loss of  1.0634 keeping weights from epoch 32 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 20466s 33s/step - loss: 0.2664 - accuracy: 0.9893 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0671 - val_accuracy: 0.7944 - val_top_k_categorical_accuracy: 0.9415
# Epoch 37/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9899 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0690 is  0.5328 % above lowest loss of  1.0634 keeping weights from epoch 32 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 20573s 33s/step - loss: 0.2661 - accuracy: 0.9899 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0690 - val_accuracy: 0.7962 - val_top_k_categorical_accuracy: 0.9408
# Epoch 38/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9902 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0660 is  0.2466 % above lowest loss of  1.0634 keeping weights from epoch 32 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
# 618/618 [==============================] - 20367s 33s/step - loss: 0.2664 - accuracy: 0.9902 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0660 - val_accuracy: 0.7962 - val_top_k_categorical_accuracy: 0.9412
# Epoch 39/40
# 618/618 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9894 - top_k_categorical_accuracy: 1.0000
#  validation loss of  1.0721 is  0.8222 % above lowest loss of  1.0634 keeping weights from epoch 32 as best weights
#
# learning rate was automatically adjusted from 0.000000 to 0.000000, model weights set to best weights
#
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
#
# h
# you entered h,  Training halted on epoch 39 due to user input
#
#
# 618/618 [==============================] - 23598s 38s/step - loss: 0.2676 - accuracy: 0.9894 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0721 - val_accuracy: 0.7966 - val_top_k_categorical_accuracy: 0.9396
# loading model with weights from epoch 32
#
# training elapsed time was 249.0 hours, 35.0 minutes, 52.07 seconds)

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')    
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(25,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')    
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    plt.tight_layout    
    plt.show()
    return index_loss
    
loss_index=tr_plot(history,0)

# %%
def predictor(test_gen):    
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]
            error_list.append(file)
            error_class=classes[pred_index]
            error_pred_list.append(error_class)
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    msg=f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}'
    print_in_color(msg, (0,255,255), (100,100,100)) # cyan foreground
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests, error_list, error_pred_list, f1score

errors, tests, error_list, error_pred_list, f1score =predictor(test_gen)
# Out:
# 4002/4002 [==============================] - 3781s 943ms/step
# there were 1490 errors in 4002 tests for an accuracy of  62.77
# Classification Report:
# ----------------------
#                             precision    recall  f1-score   support
#
#   Acne and Rosacea Photos     0.8012    0.8526    0.8261       312
# Actinic Keratosis Basal C     0.6703    0.6424    0.6560       288
#  Atopic Dermatitis Photos     0.5940    0.6423    0.6172       123
#    Bullous Disease Photos     0.5446    0.5398    0.5422       113
# Cellulitis Impetigo and o     0.4444    0.4384    0.4414        73
#             Eczema Photos     0.6075    0.5761    0.5914       309
# Exanthems and Drug Erupti     0.4628    0.5545    0.5045       101
# Hair Loss Photos Alopecia     0.4778    0.7167    0.5733        60
# Herpes HPV and other STDs     0.4786    0.5490    0.5114       102
# Light Diseases and Disord     0.5679    0.6434    0.6033       143
# Lupus and other Connectiv     0.5514    0.5619    0.5566       105
# Melanoma Skin Cancer Nevi     0.6667    0.7759    0.7171       116
# Nail Fungus and other Nai     0.8016    0.7739    0.7875       261
# Poison Ivy Photos and oth     0.5645    0.5385    0.5512        65
# Psoriasis pictures Lichen     0.5907    0.4716    0.5245       352
# Scabies Lyme Disease and      0.5413    0.5463    0.5438       108
# Seborrheic Keratoses and      0.6774    0.6122    0.6432       343
#          Systemic Disease     0.5087    0.5789    0.5415       152
# Tinea Ringworm Candidiasi     0.7029    0.5969    0.6456       325
#           Urticaria Hives     0.5965    0.6415    0.6182        53
#           Vascular Tumors     0.6891    0.6777    0.6833       121
#         Vasculitis Photos     0.5315    0.7238    0.6129       105
# Warts Molluscum and other     0.6259    0.6213    0.6236       272
#
#                  accuracy                         0.6277      4002
#                 macro avg     0.5955    0.6207    0.6050      4002
#              weighted avg     0.6322    0.6277    0.6275      4002

# %%
if len(error_list) > 0 and len(error_list)<50:
    print ('Below is a list of test files that were miss classified \n')
    print ('{0:^30s}{1:^30s}'.format('Test File', ' Predicted as'))
    sorted_list=sorted(error_list)
    for i in range(len(sorted_list)):
        fpath=sorted_list[i]        
        split=fpath.split('\\')        
        f=split[4]+ '-' + split[5]
        print(f'{f:^30s}{error_pred_list[i]:^30s}')
else:
    msg='There we more than 50 classification errors'
    print_in_color(msg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 if len(error_list) > 0 and len(error_list)<50:
#       2     print ('Below is a list of test files that were miss classified \n')
#       3     print ('{0:^30s}{1:^30s}'.format('Test File', ' Predicted as'))
#
# NameError: name 'error_list' is not defined

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    t5acc=tr_data.history['top_k_categorical_accuracy']
    v5acc=tr_data.history['val_top_k_categorical_accuracy']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')    
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=3, figsize=(25,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')    
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    axes[2].plot (Epochs,t5acc,'r',label= 'Training top 5 Accuracy')
    axes[2].scatter(Epochs, t5acc, s=100, c='green')
    axes[2].plot (Epochs,v5acc,'g',label= 'Validation top 5 Accuracy')
    axes[2].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'pink', label=vc_label)
    axes[2].set_title('Training and Validation Accuracy')
    axes[2].set_xlabel('Epochs', fontsize=18)
    axes[2].set_ylabel('Accuracy', fontsize=18)
    axes[2].legend()
    plt.tight_layout    
    plt.show()
    return index_loss
    
loss_index=tr_plot(history,0)

# %%
def predictor(test_gen):    
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]
            error_list.append(file)
            error_class=classes[pred_index]
            error_pred_list.append(error_class)
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    msg=f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}'
    print_in_color(msg, (0,255,255), (100,100,100)) # cyan foreground
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests, error_list, error_pred_list, f1score

errors, tests, error_list, error_pred_list, f1score =predictor(test_gen)
# Out:
# 4002/4002 [==============================] - 5292s 1s/step
# there were 1470 errors in 4002 tests for an accuracy of  63.27
# Classification Report:
# ----------------------
#                             precision    recall  f1-score   support
#
#   Acne and Rosacea Photos     0.8190    0.8558    0.8370       312
# Actinic Keratosis Basal C     0.6835    0.6597    0.6714       288
#  Atopic Dermatitis Photos     0.6056    0.6992    0.6491       123
#    Bullous Disease Photos     0.6395    0.4867    0.5528       113
# Cellulitis Impetigo and o     0.4429    0.4247    0.4336        73
#             Eczema Photos     0.6471    0.5696    0.6059       309
# Exanthems and Drug Erupti     0.4874    0.5743    0.5273       101
# Hair Loss Photos Alopecia     0.4896    0.7833    0.6026        60
# Herpes HPV and other STDs     0.4603    0.5686    0.5088       102
# Light Diseases and Disord     0.5110    0.6503    0.5723       143
# Lupus and other Connectiv     0.5895    0.5333    0.5600       105
# Melanoma Skin Cancer Nevi     0.6383    0.7759    0.7004       116
# Nail Fungus and other Nai     0.7961    0.7778    0.7868       261
# Poison Ivy Photos and oth     0.6731    0.5385    0.5983        65
# Psoriasis pictures Lichen     0.6364    0.4972    0.5582       352
# Scabies Lyme Disease and      0.5500    0.5093    0.5288       108
# Seborrheic Keratoses and      0.6856    0.5977    0.6386       343
#          Systemic Disease     0.4920    0.6053    0.5428       152
# Tinea Ringworm Candidiasi     0.6344    0.6246    0.6295       325
#           Urticaria Hives     0.5965    0.6415    0.6182        53
#           Vascular Tumors     0.6286    0.7273    0.6743       121
#         Vasculitis Photos     0.5833    0.6667    0.6222       105
# Warts Molluscum and other     0.6250    0.6066    0.6157       272
#
#                  accuracy                         0.6327      4002
#                 macro avg     0.6050    0.6249    0.6102      4002
#              weighted avg     0.6387    0.6327    0.6322      4002
